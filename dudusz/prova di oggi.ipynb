# %%
pip install Django djangorestframework
# Out:
# ...
#      ---------------------------------------- 8.1/8.1 MB 24.6 MB/s eta 0:00:00
# ...
#   Using cached djangorestframework-3.14.0-py3-none-any.whl (1.1 MB)
# ...
#   Using cached sqlparse-0.4.3-py3-none-any.whl (42 kB)
# ...
#   Using cached asgiref-3.5.2-py3-none-any.whl (22 kB)
# ...
#      ---------------------------------------- 338.8/338.8 kB ? eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
django-admin startproject countryapi
# Out:
#   File "C:\Users\matteolai\AppData\Local\Temp\ipykernel_10412\2573179797.py", line 1
#     django-admin startproject countryapi
#                  ^
# SyntaxError: invalid syntax

# %%
Microsoft Windows [Version 10.0.19045.2251]
(c) Microsoft Corporation. All rights reserved.

C:\Users\matteolai> cd \Users\matteolai\flask_matteo\venv\venv\

C:\Users\matteolai\flask_matteo\venv\venv> python cracovia.py

C:\Users\matteolai\flask_matteo\venv\venv>python run cracovia.py
python: can't open file 'C:\Users\matteolai\flask_matteo\venv\venv\run': [Errno 2] No such file or directory

C:\Users\matteolai\flask_matteo\venv\venv> cd \Users\matteolai\django_project\

C:\Users\matteolai\django_project>py -m venv env

C:\Users\matteolai\django_project>.\env\Scripts\activate

(env) C:\Users\matteolai\django_project>pip install Django djangorestframework
Collecting Django
  Using cached Django-4.1.3-py3-none-any.whl (8.1 MB)
Collecting djangorestframework
  Using cached djangorestframework-3.14.0-py3-none-any.whl (1.1 MB)
Collecting asgiref<4,>=3.5.2
  Using cached asgiref-3.5.2-py3-none-any.whl (22 kB)
Collecting tzdata
  Using cached tzdata-2022.6-py2.py3-none-any.whl (338 kB)
Collecting sqlparse>=0.2.2
  Using cached sqlparse-0.4.3-py3-none-any.whl (42 kB)
Collecting pytz
  Using cached pytz-2022.6-py2.py3-none-any.whl (498 kB)
Installing collected packages: pytz, tzdata, sqlparse, asgiref, Django, djangorestframework
Successfully installed Django-4.1.3 asgiref-3.5.2 djangorestframework-3.14.0 pytz-2022.6 sqlparse-0.4.3 tzdata-2022.6

[notice] A new release of pip available: 22.2.2 -> 22.3.1
[notice] To update, run: python.exe -m pip install --upgrade pip

(env) C:\Users\matteolai\django_project>django-admin startproject countryapi

(env) C:\Users\matteolai\django_project> cd \Users\matteolai\django_project\countryapi\

(env) C:\Users\matteolai\django_project\countryapi> python manage.py startapp countries

(env) C:\Users\matteolai\django_project\countryapi> python manage.py makemigrations
Migrations for 'countries':
  countries\migrations\0001_initial.py
    - Create model Country

(env) C:\Users\matteolai\django_project\countryapi>python manage.py migrate
Operations to perform:
  Apply all migrations: admin, auth, contenttypes, countries, sessions
Running migrations:
  Applying contenttypes.0001_initial... OK
  Applying auth.0001_initial... OK
  Applying admin.0001_initial... OK
  Applying admin.0002_logentry_remove_auto_add... OK
  Applying admin.0003_logentry_add_action_flag_choices... OK
  Applying contenttypes.0002_remove_content_type_name... OK
  Applying auth.0002_alter_permission_name_max_length... OK
  Applying auth.0003_alter_user_email_max_length... OK
  Applying auth.0004_alter_user_username_opts... OK
  Applying auth.0005_alter_user_last_login_null... OK
  Applying auth.0006_require_contenttypes_0002... OK
  Applying auth.0007_alter_validators_add_error_messages... OK
  Applying auth.0008_alter_user_username_max_length... OK
  Applying auth.0009_alter_user_last_name_max_length... OK
  Applying auth.0010_alter_group_name_max_length... OK
  Applying auth.0011_update_proxy_permissions... OK
  Applying auth.0012_alter_user_first_name_max_length... OK
  Applying countries.0001_initial... OK
  Applying sessions.0001_initial... OK

(env) C:\Users\matteolai\django_project\countryapi>python manage.py loaddata countries.json
CommandError: No fixture named 'countries' found.

(env) C:\Users\matteolai\django_project\countryapi> cd \countries\
The system cannot find the path specified.

(env) C:\Users\matteolai\django_project\countryapi> cd \Users\matteolai\django_project\countryapi\countries\

(env) C:\Users\matteolai\django_project\countryapi\countries>python manage.py loaddata countries.json
C:\Users\matteolai\AppData\Local\Programs\Python\Python310\python.exe: can't open file 'C:\\Users\\matteolai\\django_project\\countryapi\\countries\\manage.py': [Errno 2] No such file or directory

(env) C:\Users\matteolai\django_project\countryapi\countries>python manage.py loaddata countries.json
C:\Users\matteolai\AppData\Local\Programs\Python\Python310\python.exe: can't open file 'C:\\Users\\matteolai\\django_project\\countryapi\\countries\\manage.py': [Errno 2] No such file or directory

(env) C:\Users\matteolai\django_project\countryapi\countries> cd \Users\matteolai\django_project\countryapi\

(env) C:\Users\matteolai\django_project\countryapi>python manage.py loaddata countries.json
CommandError: No fixture named 'countries' found.

(env) C:\Users\matteolai\django_project\countryapi>python manage.py django_project/countryapi/countries.json
Unknown command: 'django_project/countryapi/countries.json'
Type 'manage.py help' for usage.

(env) C:\Users\matteolai\django_project\countryapi>manage.py help

(env) C:\Users\matteolai\django_project\countryapi>python manage.py loaddata 'countries.json'
CommandError: Problem installing fixture ''countries': json' is not a known serialization format.

(env) C:\Users\matteolai\django_project\countryapi>python manage.py loaddata <countries>.json
Access is denied.

(env) C:\Users\matteolai\django_project\countryapi>python manage.py loaddata <countries>.json
Access is denied.

(env) C:\Users\matteolai\django_project\countryapi>python manage.py loaddata --countries.json
usage: manage.py loaddata [-h] [--database DATABASE] [--app APP_LABEL] [--ignorenonexistent] [-e EXCLUDE]
                          [--format FORMAT] [--version] [-v {0,1,2,3}] [--settings SETTINGS] [--pythonpath PYTHONPATH]
                          [--traceback] [--no-color] [--force-color] [--skip-checks]
                          fixture [fixture ...]
manage.py loaddata: error: the following arguments are required: fixture

(env) C:\Users\matteolai\django_project\countryapi>python manage.py runserver
Watching for file changes with StatReloader
Performing system checks...

System check identified no issues (0 silenced).
November 23, 2022 - 17:50:53
Django version 4.1.3, using settings 'countryapi.settings'
Starting development server at http://127.0.0.1:8000/
Quit the server with CTRL-BREAK.
[23/Nov/2022 17:51:07] "GET / HTTP/1.1" 200 10681
[23/Nov/2022 17:51:07] "GET /static/admin/css/fonts.css HTTP/1.1" 200 423
[23/Nov/2022 17:51:07] "GET /static/admin/fonts/Roboto-Regular-webfont.woff HTTP/1.1" 200 85876
[23/Nov/2022 17:51:07] "GET /static/admin/fonts/Roboto-Bold-webfont.woff HTTP/1.1" 200 86184
[23/Nov/2022 17:51:07] "GET /static/admin/fonts/Roboto-Light-webfont.woff HTTP/1.1" 200 85692
Not Found: /favicon.ico
[23/Nov/2022 17:51:07] "GET /favicon.ico HTTP/1.1" 404 2114
